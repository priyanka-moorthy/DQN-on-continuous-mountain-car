# %%
import gym
import numpy as np
import torch
import matplotlib
import matplotlib.pyplot as plt
import time

from collections import deque

# %%
GAMMA = 0.99
LEARNING_RATE = 0.01
TARGET_UPDATE = 10

n_episodes = 100000
hidden_dim = 12
min_eps = 0.01
max_eps_episode = 50

# %% [markdown]
# ### NN - Q Network

# %%
import torch.nn as nn

class QNN(nn.Module):
    def __init__(self, ip_dim, op_dim, hid_dim) -> None:
        
        super(QNN, self).__init__()
        self.layer1 = torch.nn.Sequential(
            torch.nn.Linear(ip_dim, hid_dim),
            torch.nn.PReLU()
        )

        self.layer2 = torch.nn.Sequential(
            torch.nn.Linear(hid_dim, hid_dim),
            torch.nn.PReLU()
        )

        self.layer3 = torch.nn.Sequential(
            torch.nn.Linear(hid_dim, hid_dim),
            torch.nn.PReLU()
        )
        
        self.final = torch.nn.Linear(hid_dim, op_dim)
        
    def forward(self, t: torch.Tensor) -> torch.Tensor:
        t = self.layer1(t)
        t = self.layer2(t)
        t = self.layer3(t)
        t = self.final(t)

        return t

# %% [markdown]
# ## relay memory
#
# reference: https://docs.python.org/3/library/collections.html#collections.namedtuple

# %%
import random
from collections import namedtuple

transition = namedtuple('transition',('state', 'action', 'reward','nxt_state','stop'))

class ReplayMemory_CyclicBuffer(object):
    
    def __init__(self, capacity):
        self.memory = deque([], maxlen=capacity) 
            
    def __len__(self):
        return len(self.memory)
        
    def push_to_memory(self, *args):
        self.memory.append(transition(*args))
        
    def random_sampling(self, batch_size):
        return random.sample(self.memory, batch_size)
    
    
# test = transition(((1,2),(2,3),(4,5)),('stay','left','right'),(1,1,1),((4,5),(6,7),(8,9)))
# print(test)

# %% [markdown]
# ## Agent

# %%
import torch.optim as optim

from torch.autograd import Variable

BATCH_SIZE = 64
FloatTensor = torch.FloatTensor #32-bit float multi dimension matrix

class Agent_MountainCart(object):
    
    def __init__(self, n_states, n_actions, hidden_dim, learning_rate):
        self.device = torch.device("cpu")
        self.local_q = QNN(n_states, n_actions, hidden_dim).to(self.device)
        self.target_q = QNN(n_states, n_actions, hidden_dim).to(self.device)
        
        self.mse_loss = torch.nn.MSELoss()
        self.optim = optim.Adam(self.local_q.parameters(), lr=learning_rate)
        
        self.n_states = n_states
        self.n_actions = n_actions
        
        self.replay_memory = ReplayMemory_CyclicBuffer(10000)
        
        
    def get_action(self, state, eps_greedy, eps_flag = True):
        global steps_done
        
        random_sample = random.random()
        
        if random_sample > eps_greedy:
            with torch.no_grad():
                return self.local_q((state).type(FloatTensor)).data.max(1)[1].view(1,1)
        else:
            return torch.tensor([[random.randrange(self.n_actions)]])
        
    def learn(self, experience, GAMMA):
        
        if len(self.replay_memory.memory) < BATCH_SIZE:
            return;
        
        transitions_sample = self.replay_memory.random_sampling(BATCH_SIZE)
        batch = transition(*zip(*transitions_sample))
        
        states = torch.cat(batch.state)
        actions = torch.cat(batch.action)
        rewards = torch.cat(batch.reward)
        nxt_states = torch.cat(batch.nxt_state)
        stops = torch.cat(batch.stop)
        
        expected_Q = torch.gather(self.local_q(states),1,actions)
        nxt_targets_Q = self.target_q(nxt_states).detach().max(1)[0]
        targets_Q = rewards + (GAMMA * nxt_targets_Q * (1-stops)) #1-dones
        self.local_q.train(mode = True)
        self.optim.zero_grad()
        loss = self.mse_loss(expected_Q, targets_Q.unsqueeze(1))
        loss.backward()
        self.optim.step()

# %%
# set up matplotlib
is_ipython = 'inline' in matplotlib.get_backend()
if is_ipython:
    from IPython import display

plt.ion()

# %%
env = gym.make('MountainCar-v0')

dim_space = env.observation_space.shape[0]
dim_action = env.action_space.n

threshold = env.spec.reward_threshold

print('ip_dim:', dim_space, 'op_dim:', dim_action,'hidden_dim:',hidden_dim,'threshold:', threshold)

agent = Agent_MountainCart(dim_space, dim_action, hidden_dim, learning_rate=LEARNING_RATE)

def epsilon_annealing(i_episode, max_episode, min_eps: float):
    
    slope = (min_eps - 1.0)/max_episode
    max_eps = max(slope * i_episode + 1.0, min_eps)
    return max_eps

def save_q(directory, filename):
    torch.save(agent.local_q.state_dict(), '%s/%s_local.pth' % (directory, filename))
    torch.save(agent.target_q.state_dict(), '%s/%s_target.pth' % (directory, filename))
# Out:
# ip_dim: 2 op_dim: 3 hidden_dim: 12 threshold: -110.0

# %%
def play_episode(env, agent, eps):
    
    state = env.reset()
    stop = False
    total_reward = 0
    
    while not stop:
        action = agent.get_action(FloatTensor([state]), eps)
        nxt_state, reward, stop, _ = env.step(action.item())
        total_reward = total_reward + reward
        
        if stop:
            reward = -1
            
        agent.replay_memory.push_to_memory(
            FloatTensor([state]),
             action,
             FloatTensor([reward]),
             FloatTensor([nxt_state]),
             FloatTensor([stop])
        )
        
        if(len(agent.replay_memory) > BATCH_SIZE):
            batch = agent.replay_memory.random_sampling(BATCH_SIZE)
            agent.learn(batch, GAMMA)
            
        state = nxt_state
        
    return total_reward

# %%
def train():
    scores = deque(maxlen=100)
    temp_scores = []
    avg_scores = []
    
    start_time = time.time()
    
    for i_episode in range(n_episodes):
        eps = epsilon_annealing(i_episode, max_eps_episode, min_eps)
        score = play_episode(env, agent, eps)
        
        scores.append(score)
        temp_scores.append(score)
        
        avg_score = np.mean(scores)
        avg_scores.append(avg_score)
        
        dt = (int)(time.time() - start_time)
        
        if i_episode % 10 == 0 and i_episode > 0:
            print('Episode: {:5} Score: {:5}  Avg.Score: {:.2f}, eps-greedy: {:5.3f} Time: {:02}:{:02}:{:02}'.\
                    format(i_episode, score, avg_score, eps, dt//3600, dt%3600//60, dt%60))
            
        if len(scores) == 100 and  avg_score >= threshold: 
                print('\n MountainCart solved in {:d} episodes!\tAverage Score: {:.2f}'. \
                    format(i_episode, np.mean(scores)))
                break
                
        if i_episode % TARGET_UPDATE == 0:
            agent.target_q.load_state_dict(agent.local_q.state_dict()) 
                
    return temp_scores, avg_scores

scores, avg_scores = train()
save_q('gym_agents','MountainCar')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:8: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:201.)
# Episode:    10 Score: -200.0  Avg.Score: -200.00, eps-greedy: 0.802 Time: 00:00:08
# Episode:    20 Score: -200.0  Avg.Score: -200.00, eps-greedy: 0.604 Time: 00:00:14
# Episode:    30 Score: -200.0  Avg.Score: -200.00, eps-greedy: 0.406 Time: 00:00:19
# Episode:    40 Score: -200.0  Avg.Score: -200.00, eps-greedy: 0.208 Time: 00:00:27
# Episode:    50 Score: -200.0  Avg.Score: -200.00, eps-greedy: 0.010 Time: 00:00:34
# Episode:    60 Score: -200.0  Avg.Score: -200.00, eps-greedy: 0.010 Time: 00:00:47
# Episode:    70 Score: -200.0  Avg.Score: -200.00, eps-greedy: 0.010 Time: 00:00:59
# Episode:    80 Score: -200.0  Avg.Score: -200.00, eps-greedy: 0.010 Time: 00:01:12
# Episode:    90 Score: -200.0  Avg.Score: -200.00, eps-greedy: 0.010 Time: 00:01:27
# Episode:   100 Score: -200.0  Avg.Score: -200.00, eps-greedy: 0.010 Time: 00:01:33
# Episode:   110 Score: -200.0  Avg.Score: -200.00, eps-greedy: 0.010 Time: 00:01:39
# Episode:   120 Score: -200.0  Avg.Score: -200.00, eps-greedy: 0.010 Time: 00:01:47
# Episode:   130 Score: -200.0  Avg.Score: -200.00, eps-greedy: 0.010 Time: 00:01:53
# Episode:   140 Score: -200.0  Avg.Score: -200.00, eps-greedy: 0.010 Time: 00:02:01
# Episode:   150 Score: -200.0  Avg.Score: -200.00, eps-greedy: 0.010 Time: 00:02:08
# Episode:   160 Score: -200.0  Avg.Score: -200.00, eps-greedy: 0.010 Time: 00:02:15
# Episode:   170 Score: -200.0  Avg.Score: -200.00, eps-greedy: 0.010 Time: 00:02:22
# Episode:   180 Score: -200.0  Avg.Score: -200.00, eps-greedy: 0.010 Time: 00:02:29
# Episode:   190 Score: -200.0  Avg.Score: -200.00, eps-greedy: 0.010 Time: 00:02:36
# Episode:   200 Score: -200.0  Avg.Score: -200.00, eps-greedy: 0.010 Time: 00:02:44
# Episode:   210 Score: -200.0  Avg.Score: -200.00, eps-greedy: 0.010 Time: 00:02:52
# Episode:   220 Score: -200.0  Avg.Score: -200.00, eps-greedy: 0.010 Time: 00:03:00
# Episode:   230 Score: -200.0  Avg.Score: -200.00, eps-greedy: 0.010 Time: 00:03:07
# Episode:   240 Score: -200.0  Avg.Score: -200.00, eps-greedy: 0.010 Time: 00:03:16
# Episode:   250 Score: -200.0  Avg.Score: -199.51, eps-greedy: 0.010 Time: 00:03:24
# Episode:   260 Score: -200.0  Avg.Score: -199.51, eps-greedy: 0.010 Time: 00:03:31
# Episode:   270 Score: -200.0  Avg.Score: -199.51, eps-greedy: 0.010 Time: 00:03:38
# Episode:   280 Score: -200.0  Avg.Score: -199.51, eps-greedy: 0.010 Time: 00:03:45
# Episode:   290 Score: -200.0  Avg.Score: -199.51, eps-greedy: 0.010 Time: 00:03:51
# Episode:   300 Score: -200.0  Avg.Score: -199.51, eps-greedy: 0.010 Time: 00:03:59
# Episode:   310 Score: -200.0  Avg.Score: -199.51, eps-greedy: 0.010 Time: 00:04:05
# Episode:   320 Score: -200.0  Avg.Score: -199.51, eps-greedy: 0.010 Time: 00:04:11
# Episode:   330 Score: -200.0  Avg.Score: -199.51, eps-greedy: 0.010 Time: 00:04:17
# Episode:   340 Score: -200.0  Avg.Score: -199.51, eps-greedy: 0.010 Time: 00:04:28
# Episode:   350 Score: -200.0  Avg.Score: -200.00, eps-greedy: 0.010 Time: 00:04:46
# Episode:   360 Score: -200.0  Avg.Score: -199.84, eps-greedy: 0.010 Time: 00:04:54
# Episode:   370 Score: -200.0  Avg.Score: -199.84, eps-greedy: 0.010 Time: 00:05:02
# Episode:   380 Score: -200.0  Avg.Score: -199.84, eps-greedy: 0.010 Time: 00:05:10
# Episode:   390 Score: -200.0  Avg.Score: -199.84, eps-greedy: 0.010 Time: 00:05:18
# Episode:   400 Score: -200.0  Avg.Score: -199.84, eps-greedy: 0.010 Time: 00:05:32
# Episode:   410 Score: -200.0  Avg.Score: -199.84, eps-greedy: 0.010 Time: 00:05:38
# Episode:   420 Score: -200.0  Avg.Score: -199.24, eps-greedy: 0.010 Time: 00:05:46
# Episode:   430 Score: -200.0  Avg.Score: -199.21, eps-greedy: 0.010 Time: 00:06:00
# Episode:   440 Score: -200.0  Avg.Score: -198.47, eps-greedy: 0.010 Time: 00:06:12
# Episode:   450 Score: -200.0  Avg.Score: -198.47, eps-greedy: 0.010 Time: 00:06:19
# Episode:   460 Score: -200.0  Avg.Score: -198.63, eps-greedy: 0.010 Time: 00:06:25
# Episode:   470 Score: -200.0  Avg.Score: -198.63, eps-greedy: 0.010 Time: 00:06:31
# Episode:   480 Score: -200.0  Avg.Score: -198.63, eps-greedy: 0.010 Time: 00:06:38
# Episode:   490 Score: -150.0  Avg.Score: -198.13, eps-greedy: 0.010 Time: 00:06:44
# Episode:   500 Score: -200.0  Avg.Score: -197.74, eps-greedy: 0.010 Time: 00:06:50
# Episode:   510 Score: -200.0  Avg.Score: -197.12, eps-greedy: 0.010 Time: 00:06:56
# Episode:   520 Score: -200.0  Avg.Score: -195.94, eps-greedy: 0.010 Time: 00:07:02
# Episode:   530 Score: -200.0  Avg.Score: -195.41, eps-greedy: 0.010 Time: 00:07:08
# Episode:   540 Score: -200.0  Avg.Score: -195.08, eps-greedy: 0.010 Time: 00:07:14
# Episode:   550 Score: -200.0  Avg.Score: -194.56, eps-greedy: 0.010 Time: 00:07:20
# Episode:   560 Score: -200.0  Avg.Score: -194.56, eps-greedy: 0.010 Time: 00:07:27
# Episode:   570 Score: -200.0  Avg.Score: -194.56, eps-greedy: 0.010 Time: 00:07:34
# Episode:   580 Score: -200.0  Avg.Score: -193.97, eps-greedy: 0.010 Time: 00:07:40
# Episode:   590 Score: -200.0  Avg.Score: -194.47, eps-greedy: 0.010 Time: 00:07:47
# Episode:   600 Score: -200.0  Avg.Score: -194.86, eps-greedy: 0.010 Time: 00:07:53
# Episode:   610 Score: -200.0  Avg.Score: -195.48, eps-greedy: 0.010 Time: 00:07:59
# Episode:   620 Score: -200.0  Avg.Score: -196.72, eps-greedy: 0.010 Time: 00:08:05
# Episode:   630 Score: -200.0  Avg.Score: -196.95, eps-greedy: 0.010 Time: 00:08:11
# Episode:   640 Score: -200.0  Avg.Score: -197.49, eps-greedy: 0.010 Time: 00:08:17
# Episode:   650 Score: -200.0  Avg.Score: -197.90, eps-greedy: 0.010 Time: 00:08:23
# Episode:   660 Score: -163.0  Avg.Score: -197.07, eps-greedy: 0.010 Time: 00:08:29
# Episode:   670 Score: -200.0  Avg.Score: -196.65, eps-greedy: 0.010 Time: 00:08:35
# Episode:   680 Score: -200.0  Avg.Score: -196.29, eps-greedy: 0.010 Time: 00:08:40
# Episode:   690 Score: -200.0  Avg.Score: -195.91, eps-greedy: 0.010 Time: 00:08:46
# Episode:   700 Score: -112.0  Avg.Score: -194.51, eps-greedy: 0.010 Time: 00:08:52
# Episode:   710 Score: -198.0  Avg.Score: -192.26, eps-greedy: 0.010 Time: 00:08:58
# Episode:   720 Score: -200.0  Avg.Score: -192.05, eps-greedy: 0.010 Time: 00:09:04
# Episode:   730 Score: -200.0  Avg.Score: -191.44, eps-greedy: 0.010 Time: 00:09:10
# Episode:   740 Score: -200.0  Avg.Score: -191.29, eps-greedy: 0.010 Time: 00:09:16
# Episode:   750 Score: -200.0  Avg.Score: -190.55, eps-greedy: 0.010 Time: 00:09:22
# Episode:   760 Score: -200.0  Avg.Score: -190.41, eps-greedy: 0.010 Time: 00:09:30
# Episode:   770 Score: -200.0  Avg.Score: -190.83, eps-greedy: 0.010 Time: 00:09:37
# Episode:   780 Score: -200.0  Avg.Score: -190.45, eps-greedy: 0.010 Time: 00:09:46
# Episode:   790 Score: -109.0  Avg.Score: -187.29, eps-greedy: 0.010 Time: 00:09:53
# Episode:   800 Score: -200.0  Avg.Score: -186.07, eps-greedy: 0.010 Time: 00:10:01
# Episode:   810 Score: -184.0  Avg.Score: -186.60, eps-greedy: 0.010 Time: 00:10:08
# Episode:   820 Score: -200.0  Avg.Score: -186.29, eps-greedy: 0.010 Time: 00:10:17
# Episode:   830 Score: -200.0  Avg.Score: -184.81, eps-greedy: 0.010 Time: 00:10:22
# Episode:   840 Score: -200.0  Avg.Score: -183.87, eps-greedy: 0.010 Time: 00:10:29
# Episode:   850 Score: -133.0  Avg.Score: -180.80, eps-greedy: 0.010 Time: 00:10:34
# Episode:   860 Score: -174.0  Avg.Score: -177.82, eps-greedy: 0.010 Time: 00:10:41
# Episode:   870 Score: -200.0  Avg.Score: -173.90, eps-greedy: 0.010 Time: 00:10:47
# Episode:   880 Score: -131.0  Avg.Score: -167.76, eps-greedy: 0.010 Time: 00:10:51
# Episode:   890 Score: -115.0  Avg.Score: -165.28, eps-greedy: 0.010 Time: 00:11:00
# Episode:   900 Score: -184.0  Avg.Score: -161.13, eps-greedy: 0.010 Time: 00:11:05
# Episode:   910 Score: -119.0  Avg.Score: -156.20, eps-greedy: 0.010 Time: 00:11:11
# Episode:   920 Score: -121.0  Avg.Score: -150.03, eps-greedy: 0.010 Time: 00:11:16
# Episode:   930 Score: -117.0  Avg.Score: -144.63, eps-greedy: 0.010 Time: 00:11:20
# Episode:   940 Score: -118.0  Avg.Score: -138.43, eps-greedy: 0.010 Time: 00:11:24
# Episode:   950 Score: -139.0  Avg.Score: -135.97, eps-greedy: 0.010 Time: 00:11:28
# Episode:   960 Score: -120.0  Avg.Score: -132.00, eps-greedy: 0.010 Time: 00:11:36
# Episode:   970 Score: -114.0  Avg.Score: -127.46, eps-greedy: 0.010 Time: 00:11:52
# Episode:   980 Score: -113.0  Avg.Score: -126.77, eps-greedy: 0.010 Time: 00:12:03
# Episode:   990 Score: -111.0  Avg.Score: -124.04, eps-greedy: 0.010 Time: 00:12:17
# Episode:  1000 Score: -114.0  Avg.Score: -122.48, eps-greedy: 0.010 Time: 00:12:31
# Episode:  1010 Score: -105.0  Avg.Score: -121.99, eps-greedy: 0.010 Time: 00:12:37
# Episode:  1020 Score: -113.0  Avg.Score: -121.24, eps-greedy: 0.010 Time: 00:12:44
# Episode:  1030 Score: -113.0  Avg.Score: -122.48, eps-greedy: 0.010 Time: 00:12:52
# Episode:  1040 Score: -116.0  Avg.Score: -124.38, eps-greedy: 0.010 Time: 00:12:57
# Episode:  1050 Score: -173.0  Avg.Score: -124.76, eps-greedy: 0.010 Time: 00:13:09
# Episode:  1060 Score: -200.0  Avg.Score: -130.17, eps-greedy: 0.010 Time: 00:13:23
# Episode:  1070 Score: -200.0  Avg.Score: -134.31, eps-greedy: 0.010 Time: 00:13:29
# Episode:  1080 Score: -87.0  Avg.Score: -135.28, eps-greedy: 0.010 Time: 00:13:35
# Episode:  1090 Score: -156.0  Avg.Score: -137.44, eps-greedy: 0.010 Time: 00:13:41
# Episode:  1100 Score: -132.0  Avg.Score: -140.16, eps-greedy: 0.010 Time: 00:13:47
# Episode:  1110 Score: -129.0  Avg.Score: -140.08, eps-greedy: 0.010 Time: 00:13:51
# Episode:  1120 Score: -124.0  Avg.Score: -140.61, eps-greedy: 0.010 Time: 00:13:56
# Episode:  1130 Score: -125.0  Avg.Score: -140.12, eps-greedy: 0.010 Time: 00:14:01
# Episode:  1140 Score: -118.0  Avg.Score: -139.31, eps-greedy: 0.010 Time: 00:14:07
# Episode:  1150 Score: -132.0  Avg.Score: -137.70, eps-greedy: 0.010 Time: 00:14:12
# Episode:  1160 Score: -120.0  Avg.Score: -134.06, eps-greedy: 0.010 Time: 00:14:17
# Episode:  1170 Score: -125.0  Avg.Score: -134.09, eps-greedy: 0.010 Time: 00:14:23
# Episode:  1180 Score: -129.0  Avg.Score: -135.85, eps-greedy: 0.010 Time: 00:14:27
# Episode:  1190 Score: -129.0  Avg.Score: -137.08, eps-greedy: 0.010 Time: 00:14:32
# Episode:  1200 Score: -156.0  Avg.Score: -137.49, eps-greedy: 0.010 Time: 00:14:37
# Episode:  1210 Score: -150.0  Avg.Score: -139.53, eps-greedy: 0.010 Time: 00:14:41
# Episode:  1220 Score: -164.0  Avg.Score: -141.89, eps-greedy: 0.010 Time: 00:14:46
# Episode:  1230 Score: -97.0  Avg.Score: -142.51, eps-greedy: 0.010 Time: 00:14:50
# Episode:  1240 Score: -162.0  Avg.Score: -142.35, eps-greedy: 0.010 Time: 00:14:54
# Episode:  1250 Score: -154.0  Avg.Score: -143.26, eps-greedy: 0.010 Time: 00:15:00
# Episode:  1260 Score: -153.0  Avg.Score: -141.70, eps-greedy: 0.010 Time: 00:15:06
# Episode:  1270 Score: -92.0  Avg.Score: -140.09, eps-greedy: 0.010 Time: 00:15:11
# Episode:  1280 Score: -145.0  Avg.Score: -139.48, eps-greedy: 0.010 Time: 00:15:18
# Episode:  1290 Score: -121.0  Avg.Score: -136.98, eps-greedy: 0.010 Time: 00:15:24
# Episode:  1300 Score: -139.0  Avg.Score: -136.18, eps-greedy: 0.010 Time: 00:15:31
# Episode:  1310 Score: -112.0  Avg.Score: -135.52, eps-greedy: 0.010 Time: 00:15:36
# Episode:  1320 Score: -90.0  Avg.Score: -133.37, eps-greedy: 0.010 Time: 00:15:40
# Episode:  1330 Score: -149.0  Avg.Score: -133.55, eps-greedy: 0.010 Time: 00:15:44
# Episode:  1340 Score: -94.0  Avg.Score: -132.49, eps-greedy: 0.010 Time: 00:15:48
# Episode:  1350 Score: -115.0  Avg.Score: -131.51, eps-greedy: 0.010 Time: 00:15:52
# Episode:  1360 Score: -116.0  Avg.Score: -131.36, eps-greedy: 0.010 Time: 00:15:56
# Episode:  1370 Score: -111.0  Avg.Score: -128.67, eps-greedy: 0.010 Time: 00:15:59
# Episode:  1380 Score: -117.0  Avg.Score: -126.40, eps-greedy: 0.010 Time: 00:16:03
# Episode:  1390 Score: -123.0  Avg.Score: -125.20, eps-greedy: 0.010 Time: 00:16:07
# Episode:  1400 Score: -109.0  Avg.Score: -122.03, eps-greedy: 0.010 Time: 00:16:10
# Episode:  1410 Score: -88.0  Avg.Score: -118.97, eps-greedy: 0.010 Time: 00:16:14
# Episode:  1420 Score: -112.0  Avg.Score: -117.97, eps-greedy: 0.010 Time: 00:16:18
# Episode:  1430 Score: -113.0  Avg.Score: -116.42, eps-greedy: 0.010 Time: 00:16:22
# Episode:  1440 Score: -86.0  Avg.Score: -116.13, eps-greedy: 0.010 Time: 00:16:25
# Episode:  1450 Score: -94.0  Avg.Score: -115.78, eps-greedy: 0.010 Time: 00:16:29
# Episode:  1460 Score: -87.0  Avg.Score: -115.97, eps-greedy: 0.010 Time: 00:16:33
# Episode:  1470 Score: -198.0  Avg.Score: -116.05, eps-greedy: 0.010 Time: 00:16:36
# Episode:  1480 Score: -134.0  Avg.Score: -115.39, eps-greedy: 0.010 Time: 00:16:40
# Episode:  1490 Score: -105.0  Avg.Score: -115.37, eps-greedy: 0.010 Time: 00:16:44
# Episode:  1500 Score: -172.0  Avg.Score: -117.73, eps-greedy: 0.010 Time: 00:16:49
# Episode:  1510 Score: -98.0  Avg.Score: -118.45, eps-greedy: 0.010 Time: 00:16:53
# Episode:  1520 Score: -84.0  Avg.Score: -117.70, eps-greedy: 0.010 Time: 00:16:57
# Episode:  1530 Score: -110.0  Avg.Score: -119.42, eps-greedy: 0.010 Time: 00:17:01
# Episode:  1540 Score: -148.0  Avg.Score: -119.49, eps-greedy: 0.010 Time: 00:17:05
# Episode:  1550 Score: -86.0  Avg.Score: -118.62, eps-greedy: 0.010 Time: 00:17:09
# Episode:  1560 Score: -84.0  Avg.Score: -118.19, eps-greedy: 0.010 Time: 00:17:13
# Episode:  1570 Score: -105.0  Avg.Score: -118.09, eps-greedy: 0.010 Time: 00:17:17
# Episode:  1580 Score: -111.0  Avg.Score: -117.80, eps-greedy: 0.010 Time: 00:17:20
# Episode:  1590 Score: -109.0  Avg.Score: -117.80, eps-greedy: 0.010 Time: 00:17:24
# Episode:  1600 Score: -85.0  Avg.Score: -114.68, eps-greedy: 0.010 Time: 00:17:27
# Episode:  1610 Score: -108.0  Avg.Score: -113.11, eps-greedy: 0.010 Time: 00:17:30
# Episode:  1620 Score: -125.0  Avg.Score: -113.38, eps-greedy: 0.010 Time: 00:17:34
# Episode:  1630 Score: -109.0  Avg.Score: -110.59, eps-greedy: 0.010 Time: 00:17:37
# Episode:  1640 Score: -112.0  Avg.Score: -109.79, eps-greedy: 0.010 Time: 00:17:41
#
#  MountainCart solved in 1640 episodes!	Average Score: -109.79

# %%
scores_iteration_2, avg_scores_iteration_2 = train()
# save_q('gym_agents','MountainCar')

# %%
scores_iteration_3, avg_scores_iteration_3 = train()
# save_q('gym_agents','MountainCar')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

print('scores length: ', len(scores), ', avg_scores length: ', len(avg_scores))

fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(1, len(scores)+1), scores, label="Score")
plt.plot(np.arange(1, len(avg_scores)+1), avg_scores, label="Avg on 100 episodes")
plt.legend(bbox_to_anchor=(1.05, 1)) 
plt.ylabel('Score')
plt.xlabel('Episodes #')
plt.show()
# Out:
# scores length:  1641 , avg_scores length:  1641

# %% [markdown]
# ## Watch Agent

# %%
def play_agent(env, agent, n_episodes):
    state = env.reset()
    scores = deque(maxlen=100)
    
    for i_episode in range(1, n_episodes+1):
        state = env.reset()        
        
        total_reward = 0
        start_time = time.time()
        timesteps =  0
        
        while True:
            
            a = agent.get_action(FloatTensor([state]), eps_flag=False, eps_greedy=0.01)
            env.render()
            nxt_state, r, done, _ = env.step(a.item())
            state = nxt_state
            total_reward += r
            timesteps += 1
            
            if done:
                break 

        delta = (int)(time.time() - start_time) 
        
        scores.append(total_reward)

        print('Episode {}\tAverage Score: {:.2f}, \t Timesteps: {} \tTime: {:02}:{:02}:{:02}'\
                  .format(i_episode, np.mean(scores), timesteps,\
                          delta//3600, delta%3600//60, delta%60))
        
def load(agent, directory, filename):
    agent.local_q.load_state_dict(torch.load('%s/%s_local.pth' % (directory,  filename)))
    agent.target_q.load_state_dict(torch.load('%s/%s_target.pth' % (directory,  filename)))

# %%
load(agent, 'gym_agents', 'MountainCar')
play_agent(env=env, agent=agent, n_episodes=10)
# Out:
# Episode 1	Average Score: -113.00, 	 Timesteps: 113 	Time: 00:00:07
# Episode 2	Average Score: -115.00, 	 Timesteps: 117 	Time: 00:00:02
# Episode 3	Average Score: -108.33, 	 Timesteps: 95 	Time: 00:00:01
# Episode 4	Average Score: -112.50, 	 Timesteps: 125 	Time: 00:00:02
# Episode 5	Average Score: -107.80, 	 Timesteps: 89 	Time: 00:00:01
# Episode 6	Average Score: -108.83, 	 Timesteps: 114 	Time: 00:00:01
# Episode 7	Average Score: -109.57, 	 Timesteps: 114 	Time: 00:00:02
# Episode 8	Average Score: -110.25, 	 Timesteps: 115 	Time: 00:00:01
# Episode 9	Average Score: -110.56, 	 Timesteps: 113 	Time: 00:00:00
# Episode 10	Average Score: -110.80, 	 Timesteps: 113 	Time: 00:00:00

# %%
env.close()
